# %%
# Cell 1: Import libraries
import pandas as pd
import re

# %%
# Cell 2: Load the movies dataset
movies = pd.read_csv('../backend/data/raw/movies.csv')
print(f"Original dataset shape: {movies.shape}")
print(f"Original number of movies: {len(movies)}")
# Out:
# Original dataset shape: (9742, 3)
# Original number of movies: 9742

# %%
# Cell 3: Check for missing values
print("\nMissing values:")
print(movies.isnull().sum())
# Out:
# Missing values:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
# Cell 4: Check for movies with no genres
no_genre = movies[movies['genres'] == '(no genres listed)']
print(f"\nMovies with no genres: {len(no_genre)}")
# Out:
# Movies with no genres: 34

# %%
# Cell 5: Check for duplicate movieId or title
duplicates = movies[movies.duplicated(subset=['movieId'], keep=False) | movies.duplicated(subset=['title'], keep=False)]
print(f"\nDuplicate entries: {len(duplicates)}")
# Out:
# Duplicate entries: 10

# %%
# Cell 6: Extract year from title and check for unusual years
def extract_year(title):
    match = re.search(r'\((\d{4})\)$', title)
    return int(match.group(1)) if match else None

movies['year'] = movies['title'].apply(extract_year)
unusual_years = movies[(movies['year'] < 1900) | (movies['year'] > 2023)]
print(f"\nMovies with unusual years: {len(unusual_years)}")
# Out:
# Movies with unusual years: 0

# %%
# Cell 7: Check number of genres per movie
movies['genre_count'] = movies['genres'].str.count('\|') + 1
genre_stats = movies['genre_count'].describe()
print("\nGenre count statistics:")
print(genre_stats)
# Out:
# Genre count statistics:
# count    9742.000000
# mean        2.266886
# std         1.123249
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        10.000000
# Name: genre_count, dtype: float64

# %%
# Cell 8: Suggest filtering criteria
print("\nSuggested filtering criteria:")
print("1. Remove movies with no genres")
print("2. Remove duplicate entries")
print("3. Remove movies with years before 1900 or after 2023")
# Out:
# Suggested filtering criteria:
# 1. Remove movies with no genres
# 2. Remove duplicate entries
# 3. Remove movies with years before 1900 or after 2023

# %%
# Cell 9: Apply initial filters to movies dataset
filtered_movies = movies[
    (movies['genres'] != '(no genres listed)') &
    (~movies.duplicated(subset=['movieId'], keep='first')) &
    (~movies.duplicated(subset=['title'], keep='first')) &
    (movies['year'].between(1900, 2023))
]

print(f"\nAfter initial filtering:")
print(f"Dataset shape: {filtered_movies.shape}")
print(f"Number of movies: {len(filtered_movies)}")
print(f"Removed {len(movies) - len(filtered_movies)} movies")
# Out:
# After initial filtering:
# Dataset shape: (9688, 5)
# Number of movies: 9688
# Removed 54 movies

# %%
# Cell 10: Load and apply ratings filter
# Load the filtered ratings dataset
filtered_ratings = pd.read_csv('../backend/data/processed/filtered_ratings.csv')

# Get list of movies that have enough ratings
movies_with_ratings = filtered_ratings['movieId'].unique()

# Update filtered_movies to only include movies with sufficient ratings
filtered_movies = filtered_movies[filtered_movies['movieId'].isin(movies_with_ratings)]

print(f"\nAfter ratings filter:")
print(f"Final dataset shape: {filtered_movies.shape}")
print(f"Final number of movies: {len(filtered_movies)}")
print(f"Removed by ratings filter: {len(movies) - len(filtered_movies)} movies")

# Show detailed breakdown
print("\nDetailed breakdown:")
print(f"Original movies: {len(movies)}")
print(f"After initial filters: {len(filtered_movies)}")
print(f"Movies with sufficient ratings: {len(movies_with_ratings)}")
print(f"Final movies count: {len(filtered_movies)}")
# Out:
# After ratings filter:
# Final dataset shape: (3649, 5)
# Final number of movies: 3649
# Removed by ratings filter: 6093 movies
#
# Detailed breakdown:
# Original movies: 9742
# After initial filters: 3649
# Movies with sufficient ratings: 3650
# Final movies count: 3649

# %%
# Cell 11: Clean, standardize and save final filtered dataset
print(f"Original count before standardization: {len(filtered_movies)}")

# Standardization functions
def standardize_title(title):
    # Move articles from end to beginning
    if ", The (" in title:
        title = "The " + title.replace(", The (", " (")
    if ", A (" in title:
        title = "A " + title.replace(", A (", " (")
    if ", An (" in title:
        title = "An " + title.replace(", An (", " (")
    
    # Remove any double spaces
    title = ' '.join(title.split())
    return title

def standardize_genres(genres):
    # Sort genres alphabetically for consistency
    return '|'.join(sorted(genres.split('|')))

def standardize_year(year):
    # Convert to integer
    return int(float(year))

# Count titles before standardization
the_count = sum(1 for title in filtered_movies['title'] if ", The (" in title)
a_count = sum(1 for title in filtered_movies['title'] if ", A (" in title)
an_count = sum(1 for title in filtered_movies['title'] if ", An (" in title)

# Apply standardization
filtered_movies['title'] = filtered_movies['title'].apply(standardize_title)
filtered_movies['genres'] = filtered_movies['genres'].apply(standardize_genres)
filtered_movies['year'] = filtered_movies['year'].apply(standardize_year)

# Print standardization stats
print("\nStandardization summary:")
print("------------------------")
print(f"Titles with 'The' at end before standardization: {the_count}")
print(f"Titles with 'A' at end before standardization: {a_count}")
print(f"Titles with 'An' at end before standardization: {an_count}")
print(f"Year range: {filtered_movies['year'].min()} to {filtered_movies['year'].max()}")
print(f"Number of unique genres: {len(filtered_movies['genres'].str.split('|').explode().unique())}")

# Save standardized dataset
filtered_movies.to_csv('../backend/data/processed/filtered_movies.csv', 
                      index=False,
                      quoting=1,
                      encoding='utf-8')

print("\nStandardized dataset saved to '../backend/data/processed/filtered_movies.csv'")
# Out:
# Original count before standardization: 3649
#
# Standardization summary:
# ------------------------
# Titles with 'The' at end before standardization: 689
# Titles with 'A' at end before standardization: 51
# Titles with 'An' at end before standardization: 10
# Year range: 1902 to 2018
# Number of unique genres: 19
#
# Standardized dataset saved to '../backend/data/processed/filtered_movies.csv'

# %%
# Cell 12: Remove IMAX from genres and update genre counts
print("Movies containing IMAX before cleanup:")
imax_movies = filtered_movies[filtered_movies['genres'].str.contains('IMAX')]
for _, movie in imax_movies.iterrows():
    print(f"- {movie['title']}")
    print(f"  Old genres: {movie['genres']}")
    print(f"  Old genre count: {movie['genre_count']}")
    print()

# Remove IMAX from genres and update counts
def remove_imax(genres):
    genres_list = genres.split('|')
    genres_list = [g for g in genres_list if g != 'IMAX']
    return '|'.join(sorted(genres_list))

# Apply changes
filtered_movies['genres'] = filtered_movies['genres'].apply(remove_imax)
filtered_movies['genre_count'] = filtered_movies['genres'].str.count('\\|') + 1

# Show the changes
print("\nAfter IMAX removal:")
for _, movie in imax_movies.iterrows():
    updated = filtered_movies[filtered_movies['movie_id'] == movie['movie_id']].iloc[0]
    print(f"- {updated['title']}")
    print(f"  New genres: {updated['genres']}")
    print(f"  New genre count: {updated['genre_count']}")
    print()

# Save updated dataset
filtered_movies.to_csv('../backend/data/processed/filtered_movies.csv', 
                      index=False,
                      quoting=1,
                      encoding='utf-8')

print("\nUpdated dataset saved to '../backend/data/processed/filtered_movies.csv'")
# Out:
# Movies containing IMAX before cleanup:
# - Apollo 13 (1995)
#   Old genres: Adventure|Drama|IMAX
#   Old genre count: 3
#
# - The Lion King (1994)
#   Old genres: Adventure|Animation|Children|Drama|IMAX|Musical
#   Old genre count: 6
#
# - Beauty and the Beast (1991)
#   Old genres: Animation|Children|Fantasy|IMAX|Musical|Romance
#   Old genre count: 6
#
# - Everest (1998)
#   Old genres: Documentary|IMAX
#   Old genre count: 2
#
# - Fantasia 2000 (1999)
#   Old genres: Animation|Children|IMAX|Musical
#   Old genre count: 4
#
# - Star Wars: Episode II - Attack of the Clones (2002)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Treasure Planet (2002)
#   Old genres: Adventure|Animation|Children|IMAX|Sci-Fi
#   Old genre count: 5
#
# - The Matrix Reloaded (2003)
#   Old genres: Action|Adventure|IMAX|Sci-Fi|Thriller
#   Old genre count: 5
#
# - The Matrix Revolutions (2003)
#   Old genres: Action|Adventure|IMAX|Sci-Fi|Thriller
#   Old genre count: 5
#
# - Harry Potter and the Prisoner of Azkaban (2004)
#   Old genres: Adventure|Fantasy|IMAX
#   Old genre count: 3
#
# - Spider-Man 2 (2004)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - The Polar Express (2004)
#   Old genres: Adventure|Animation|Children|Fantasy|IMAX
#   Old genre count: 5
#
# - Charlie and the Chocolate Factory (2005)
#   Old genres: Adventure|Children|Comedy|Fantasy|IMAX
#   Old genre count: 5
#
# - Robots (2005)
#   Old genres: Adventure|Animation|Children|Comedy|Fantasy|IMAX|Sci-Fi
#   Old genre count: 7
#
# - Batman Begins (2005)
#   Old genres: Action|Crime|IMAX
#   Old genre count: 3
#
# - Harry Potter and the Goblet of Fire (2005)
#   Old genres: Adventure|Fantasy|IMAX|Thriller
#   Old genre count: 4
#
# - V for Vendetta (2006)
#   Old genres: Action|IMAX|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Superman Returns (2006)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Night at the Museum (2006)
#   Old genres: Action|Comedy|Fantasy|IMAX
#   Old genre count: 4
#
# - Happy Feet (2006)
#   Old genres: Adventure|Animation|Children|Comedy|IMAX
#   Old genre count: 5
#
# - 300 (2007)
#   Old genres: Action|Fantasy|IMAX|War
#   Old genre count: 4
#
# - Spider-Man 3 (2007)
#   Old genres: Action|Adventure|IMAX|Sci-Fi|Thriller
#   Old genre count: 5
#
# - Transformers (2007)
#   Old genres: Action|IMAX|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Harry Potter and the Order of the Phoenix (2007)
#   Old genres: Adventure|Drama|Fantasy|IMAX
#   Old genre count: 4
#
# - Beowulf (2007)
#   Old genres: Action|Adventure|Animation|Fantasy|IMAX
#   Old genre count: 5
#
# - I Am Legend (2007)
#   Old genres: Action|Horror|IMAX|Sci-Fi|Thriller
#   Old genre count: 5
#
# - The Spiderwick Chronicles (2008)
#   Old genres: Adventure|Children|Drama|Fantasy|IMAX
#   Old genre count: 5
#
# - The Dark Knight (2008)
#   Old genres: Action|Crime|Drama|IMAX
#   Old genre count: 4
#
# - Kung Fu Panda (2008)
#   Old genres: Action|Animation|Children|Comedy|IMAX
#   Old genre count: 5
#
# - Watchmen (2009)
#   Old genres: Action|Drama|IMAX|Mystery|Sci-Fi|Thriller
#   Old genre count: 6
#
# - Eagle Eye (2008)
#   Old genres: Action|Crime|IMAX|Thriller
#   Old genre count: 4
#
# - Madagascar: Escape 2 Africa (2008)
#   Old genres: Action|Adventure|Animation|Children|Comedy|IMAX
#   Old genre count: 6
#
# - The Day the Earth Stood Still (2008)
#   Old genres: Drama|IMAX|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Monsters vs. Aliens (2009)
#   Old genres: Animation|IMAX|Sci-Fi
#   Old genre count: 3
#
# - Star Trek (2009)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Night at the Museum: Battle of the Smithsonian (2009)
#   Old genres: Action|Comedy|IMAX
#   Old genre count: 3
#
# - Transformers: Revenge of the Fallen (2009)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Harry Potter and the Half-Blood Prince (2009)
#   Old genres: Adventure|Fantasy|IMAX|Mystery|Romance
#   Old genre count: 5
#
# - Cloudy with a Chance of Meatballs (2009)
#   Old genres: Animation|Children|Fantasy|IMAX
#   Old genre count: 4
#
# - Where the Wild Things Are (2009)
#   Old genres: Adventure|Children|Drama|Fantasy|IMAX
#   Old genre count: 5
#
# - Avatar (2009)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Alice in Wonderland (2010)
#   Old genres: Adventure|Fantasy|IMAX
#   Old genre count: 3
#
# - How to Train Your Dragon (2010)
#   Old genres: Adventure|Animation|Children|Fantasy|IMAX
#   Old genre count: 5
#
# - Iron Man 2 (2010)
#   Old genres: Action|Adventure|IMAX|Sci-Fi|Thriller
#   Old genre count: 5
#
# - Prince of Persia: The Sands of Time (2010)
#   Old genres: Action|Adventure|Fantasy|IMAX|Romance
#   Old genre count: 5
#
# - Toy Story 3 (2010)
#   Old genres: Adventure|Animation|Children|Comedy|Fantasy|IMAX
#   Old genre count: 6
#
# - Shrek Forever After (a.k.a. Shrek: The Final Chapter) (2010)
#   Old genres: Adventure|Animation|Children|Comedy|Fantasy|IMAX
#   Old genre count: 6
#
# - The Twilight Saga: Eclipse (2010)
#   Old genres: Fantasy|IMAX|Romance|Thriller
#   Old genre count: 4
#
# - Inception (2010)
#   Old genres: Action|Crime|Drama|IMAX|Mystery|Sci-Fi|Thriller
#   Old genre count: 7
#
# - Resident Evil: Afterlife (2010)
#   Old genres: Action|Horror|IMAX|Sci-Fi|Thriller
#   Old genre count: 5
#
# - Paranormal Activity 2 (2010)
#   Old genres: Horror|IMAX
#   Old genre count: 2
#
# - Megamind (2010)
#   Old genres: Action|Animation|Children|Comedy|IMAX|Sci-Fi
#   Old genre count: 6
#
# - Harry Potter and the Deathly Hallows: Part 1 (2010)
#   Old genres: Action|Adventure|Fantasy|IMAX
#   Old genre count: 4
#
# - Tangled (2010)
#   Old genres: Animation|Children|Comedy|Fantasy|IMAX|Musical|Romance
#   Old genre count: 7
#
# - Tron: Legacy (2010)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - The Green Hornet (2011)
#   Old genres: Action|Comedy|Crime|Fantasy|IMAX|Thriller
#   Old genre count: 6
#
# - Cowboys & Aliens (2011)
#   Old genres: Action|IMAX|Sci-Fi|Thriller|Western
#   Old genre count: 5
#
# - I Am Number Four (2011)
#   Old genres: Action|IMAX|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Sucker Punch (2011)
#   Old genres: Action|Fantasy|IMAX|Thriller
#   Old genre count: 4
#
# - Thor (2011)
#   Old genres: Action|Adventure|Drama|Fantasy|IMAX
#   Old genre count: 5
#
# - Fast Five (Fast and the Furious 5, The) (2011)
#   Old genres: Action|Crime|Drama|IMAX|Thriller
#   Old genre count: 5
#
# - Pirates of the Caribbean: On Stranger Tides (2011)
#   Old genres: Action|Adventure|Fantasy|IMAX
#   Old genre count: 4
#
# - Kung Fu Panda 2 (2011)
#   Old genres: Action|Adventure|Animation|Children|Comedy|IMAX
#   Old genre count: 6
#
# - Super 8 (2011)
#   Old genres: IMAX|Mystery|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Transformers: Dark of the Moon (2011)
#   Old genres: Action|Adventure|IMAX|Sci-Fi|War
#   Old genre count: 5
#
# - Harry Potter and the Deathly Hallows: Part 2 (2011)
#   Old genres: Action|Adventure|Drama|Fantasy|IMAX|Mystery
#   Old genre count: 6
#
# - Contagion (2011)
#   Old genres: IMAX|Sci-Fi|Thriller
#   Old genre count: 3
#
# - The Avengers (2012)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Real Steel (2011)
#   Old genres: Action|Drama|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Puss in Boots (2011)
#   Old genres: Adventure|Animation|Comedy|Fantasy|IMAX
#   Old genre count: 5
#
# - The Adventures of Tintin (2011)
#   Old genres: Action|Animation|IMAX|Mystery
#   Old genre count: 4
#
# - The Dark Knight Rises (2012)
#   Old genres: Action|Adventure|Crime|IMAX
#   Old genre count: 4
#
# - The Bourne Legacy (2012)
#   Old genres: Action|Adventure|Drama|IMAX|Thriller
#   Old genre count: 5
#
# - Mission: Impossible - Ghost Protocol (2011)
#   Old genres: Action|Adventure|IMAX|Thriller
#   Old genre count: 4
#
# - Underworld: Awakening (2012)
#   Old genres: Action|Fantasy|Horror|IMAX
#   Old genre count: 4
#
# - Dr. Seuss' The Lorax (2012)
#   Old genres: Animation|Fantasy|IMAX|Musical
#   Old genre count: 4
#
# - John Carter (2012)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Dark Shadows (2012)
#   Old genres: Comedy|Horror|IMAX
#   Old genre count: 3
#
# - Men in Black III (M.III.B.) (M.I.B.³) (2012)
#   Old genres: Action|Comedy|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Prometheus (2012)
#   Old genres: Action|Horror|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Madagascar 3: Europe's Most Wanted (2012)
#   Old genres: Adventure|Animation|Children|Comedy|IMAX
#   Old genre count: 5
#
# - The Amazing Spider-Man (2012)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Skyfall (2012)
#   Old genres: Action|Adventure|IMAX|Thriller
#   Old genre count: 4
#
# - Cloud Atlas (2012)
#   Old genres: Drama|IMAX|Sci-Fi
#   Old genre count: 3
#
# - Life of Pi (2012)
#   Old genres: Adventure|Drama|IMAX
#   Old genre count: 3
#
# - Rise of the Guardians (2012)
#   Old genres: Adventure|Animation|Children|Fantasy|IMAX
#   Old genre count: 5
#
# - The Hobbit: An Unexpected Journey (2012)
#   Old genres: Adventure|Fantasy|IMAX
#   Old genre count: 3
#
# - Misérables, Les (2012)
#   Old genres: Drama|IMAX|Musical|Romance
#   Old genre count: 4
#
# - Hansel & Gretel: Witch Hunters (2013)
#   Old genres: Action|Fantasy|Horror|IMAX
#   Old genre count: 4
#
# - A Good Day to Die Hard (2013)
#   Old genres: Action|Crime|IMAX|Thriller
#   Old genre count: 4
#
# - Jack the Giant Slayer (2013)
#   Old genres: Adventure|Fantasy|IMAX
#   Old genre count: 3
#
# - Oz the Great and Powerful (2013)
#   Old genres: Action|Adventure|Fantasy|IMAX
#   Old genre count: 4
#
# - Oblivion (2013)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Iron Man 3 (2013)
#   Old genres: Action|IMAX|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Star Trek Into Darkness (2013)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Fast & Furious 6 (Fast and the Furious 6, The) (2013)
#   Old genres: Action|Crime|IMAX|Thriller
#   Old genre count: 4
#
# - Man of Steel (2013)
#   Old genres: Action|Adventure|Fantasy|IMAX|Sci-Fi
#   Old genre count: 5
#
# - Pacific Rim (2013)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - World War Z (2013)
#   Old genres: Action|Drama|Horror|IMAX
#   Old genre count: 4
#
# - Elysium (2013)
#   Old genres: Action|Drama|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Despicable Me 2 (2013)
#   Old genres: Animation|Children|Comedy|IMAX
#   Old genre count: 4
#
# - White House Down (2013)
#   Old genres: Action|Drama|IMAX|Thriller
#   Old genre count: 4
#
# - The Lone Ranger (2013)
#   Old genres: Action|Adventure|IMAX|Western
#   Old genre count: 4
#
# - Riddick (2013)
#   Old genres: Action|IMAX|Sci-Fi|Thriller
#   Old genre count: 4
#
# - Gravity (2013)
#   Old genres: Action|IMAX|Sci-Fi
#   Old genre count: 3
#
# - Captain Phillips (2013)
#   Old genres: Adventure|Drama|IMAX|Thriller
#   Old genre count: 4
#
# - Ender's Game (2013)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Thor: The Dark World (2013)
#   Old genres: Action|Adventure|Fantasy|IMAX
#   Old genre count: 4
#
# - The Hunger Games: Catching Fire (2013)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - The Hobbit: The Desolation of Smaug (2013)
#   Old genres: Adventure|Fantasy|IMAX
#   Old genre count: 3
#
# - Divergent (2014)
#   Old genres: Adventure|IMAX|Romance|Sci-Fi
#   Old genre count: 4
#
# - RoboCop (2014)
#   Old genres: Action|Crime|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Interstellar (2014)
#   Old genres: IMAX|Sci-Fi
#   Old genre count: 2
#
# - Captain America: The Winter Soldier (2014)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Noah (2014)
#   Old genres: Adventure|Drama|IMAX
#   Old genre count: 3
#
# - The Amazing Spider-Man 2 (2014)
#   Old genres: Action|IMAX|Sci-Fi
#   Old genre count: 3
#
# - Transcendence (2014)
#   Old genres: Drama|IMAX|Sci-Fi
#   Old genre count: 3
#
# - Godzilla (2014)
#   Old genres: Action|Adventure|IMAX|Sci-Fi
#   Old genre count: 4
#
# - Maleficent (2014)
#   Old genres: Action|Adventure|Children|IMAX
#   Old genre count: 4
#
# - Edge of Tomorrow (2014)
#   Old genres: Action|IMAX|Sci-Fi
#   Old genre count: 3
#
# - Star Wars: Episode VII - The Force Awakens (2015)
#   Old genres: Action|Adventure|Fantasy|IMAX|Sci-Fi
#   Old genre count: 5
#
#
# After IMAX removal:
# - Apollo 13 (1995)
#   New genres: Adventure|Drama
#   New genre count: 2
#
# - The Lion King (1994)
#   New genres: Adventure|Animation|Children|Drama|Musical
#   New genre count: 5
#
# - Beauty and the Beast (1991)
#   New genres: Animation|Children|Fantasy|Musical|Romance
#   New genre count: 5
#
# - Everest (1998)
#   New genres: Documentary
#   New genre count: 1
#
# - Fantasia 2000 (1999)
#   New genres: Animation|Children|Musical
#   New genre count: 3
#
# - Star Wars: Episode II - Attack of the Clones (2002)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Treasure Planet (2002)
#   New genres: Adventure|Animation|Children|Sci-Fi
#   New genre count: 4
#
# - The Matrix Reloaded (2003)
#   New genres: Action|Adventure|Sci-Fi|Thriller
#   New genre count: 4
#
# - The Matrix Revolutions (2003)
#   New genres: Action|Adventure|Sci-Fi|Thriller
#   New genre count: 4
#
# - Harry Potter and the Prisoner of Azkaban (2004)
#   New genres: Adventure|Fantasy
#   New genre count: 2
#
# - Spider-Man 2 (2004)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - The Polar Express (2004)
#   New genres: Adventure|Animation|Children|Fantasy
#   New genre count: 4
#
# - Charlie and the Chocolate Factory (2005)
#   New genres: Adventure|Children|Comedy|Fantasy
#   New genre count: 4
#
# - Robots (2005)
#   New genres: Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi
#   New genre count: 6
#
# - Batman Begins (2005)
#   New genres: Action|Crime
#   New genre count: 2
#
# - Harry Potter and the Goblet of Fire (2005)
#   New genres: Adventure|Fantasy|Thriller
#   New genre count: 3
#
# - V for Vendetta (2006)
#   New genres: Action|Sci-Fi|Thriller
#   New genre count: 3
#
# - Superman Returns (2006)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Night at the Museum (2006)
#   New genres: Action|Comedy|Fantasy
#   New genre count: 3
#
# - Happy Feet (2006)
#   New genres: Adventure|Animation|Children|Comedy
#   New genre count: 4
#
# - 300 (2007)
#   New genres: Action|Fantasy|War
#   New genre count: 3
#
# - Spider-Man 3 (2007)
#   New genres: Action|Adventure|Sci-Fi|Thriller
#   New genre count: 4
#
# - Transformers (2007)
#   New genres: Action|Sci-Fi|Thriller
#   New genre count: 3
#
# - Harry Potter and the Order of the Phoenix (2007)
#   New genres: Adventure|Drama|Fantasy
#   New genre count: 3
#
# - Beowulf (2007)
#   New genres: Action|Adventure|Animation|Fantasy
#   New genre count: 4
#
# - I Am Legend (2007)
#   New genres: Action|Horror|Sci-Fi|Thriller
#   New genre count: 4
#
# - The Spiderwick Chronicles (2008)
#   New genres: Adventure|Children|Drama|Fantasy
#   New genre count: 4
#
# - The Dark Knight (2008)
#   New genres: Action|Crime|Drama
#   New genre count: 3
#
# - Kung Fu Panda (2008)
#   New genres: Action|Animation|Children|Comedy
#   New genre count: 4
#
# - Watchmen (2009)
#   New genres: Action|Drama|Mystery|Sci-Fi|Thriller
#   New genre count: 5
#
# - Eagle Eye (2008)
#   New genres: Action|Crime|Thriller
#   New genre count: 3
#
# - Madagascar: Escape 2 Africa (2008)
#   New genres: Action|Adventure|Animation|Children|Comedy
#   New genre count: 5
#
# - The Day the Earth Stood Still (2008)
#   New genres: Drama|Sci-Fi|Thriller
#   New genre count: 3
#
# - Monsters vs. Aliens (2009)
#   New genres: Animation|Sci-Fi
#   New genre count: 2
#
# - Star Trek (2009)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Night at the Museum: Battle of the Smithsonian (2009)
#   New genres: Action|Comedy
#   New genre count: 2
#
# - Transformers: Revenge of the Fallen (2009)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Harry Potter and the Half-Blood Prince (2009)
#   New genres: Adventure|Fantasy|Mystery|Romance
#   New genre count: 4
#
# - Cloudy with a Chance of Meatballs (2009)
#   New genres: Animation|Children|Fantasy
#   New genre count: 3
#
# - Where the Wild Things Are (2009)
#   New genres: Adventure|Children|Drama|Fantasy
#   New genre count: 4
#
# - Avatar (2009)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Alice in Wonderland (2010)
#   New genres: Adventure|Fantasy
#   New genre count: 2
#
# - How to Train Your Dragon (2010)
#   New genres: Adventure|Animation|Children|Fantasy
#   New genre count: 4
#
# - Iron Man 2 (2010)
#   New genres: Action|Adventure|Sci-Fi|Thriller
#   New genre count: 4
#
# - Prince of Persia: The Sands of Time (2010)
#   New genres: Action|Adventure|Fantasy|Romance
#   New genre count: 4
#
# - Toy Story 3 (2010)
#   New genres: Adventure|Animation|Children|Comedy|Fantasy
#   New genre count: 5
#
# - Shrek Forever After (a.k.a. Shrek: The Final Chapter) (2010)
#   New genres: Adventure|Animation|Children|Comedy|Fantasy
#   New genre count: 5
#
# - The Twilight Saga: Eclipse (2010)
#   New genres: Fantasy|Romance|Thriller
#   New genre count: 3
#
# - Inception (2010)
#   New genres: Action|Crime|Drama|Mystery|Sci-Fi|Thriller
#   New genre count: 6
#
# - Resident Evil: Afterlife (2010)
#   New genres: Action|Horror|Sci-Fi|Thriller
#   New genre count: 4
#
# - Paranormal Activity 2 (2010)
#   New genres: Horror
#   New genre count: 1
#
# - Megamind (2010)
#   New genres: Action|Animation|Children|Comedy|Sci-Fi
#   New genre count: 5
#
# - Harry Potter and the Deathly Hallows: Part 1 (2010)
#   New genres: Action|Adventure|Fantasy
#   New genre count: 3
#
# - Tangled (2010)
#   New genres: Animation|Children|Comedy|Fantasy|Musical|Romance
#   New genre count: 6
#
# - Tron: Legacy (2010)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - The Green Hornet (2011)
#   New genres: Action|Comedy|Crime|Fantasy|Thriller
#   New genre count: 5
#
# - Cowboys & Aliens (2011)
#   New genres: Action|Sci-Fi|Thriller|Western
#   New genre count: 4
#
# - I Am Number Four (2011)
#   New genres: Action|Sci-Fi|Thriller
#   New genre count: 3
#
# - Sucker Punch (2011)
#   New genres: Action|Fantasy|Thriller
#   New genre count: 3
#
# - Thor (2011)
#   New genres: Action|Adventure|Drama|Fantasy
#   New genre count: 4
#
# - Fast Five (Fast and the Furious 5, The) (2011)
#   New genres: Action|Crime|Drama|Thriller
#   New genre count: 4
#
# - Pirates of the Caribbean: On Stranger Tides (2011)
#   New genres: Action|Adventure|Fantasy
#   New genre count: 3
#
# - Kung Fu Panda 2 (2011)
#   New genres: Action|Adventure|Animation|Children|Comedy
#   New genre count: 5
#
# - Super 8 (2011)
#   New genres: Mystery|Sci-Fi|Thriller
#   New genre count: 3
#
# - Transformers: Dark of the Moon (2011)
#   New genres: Action|Adventure|Sci-Fi|War
#   New genre count: 4
#
# - Harry Potter and the Deathly Hallows: Part 2 (2011)
#   New genres: Action|Adventure|Drama|Fantasy|Mystery
#   New genre count: 5
#
# - Contagion (2011)
#   New genres: Sci-Fi|Thriller
#   New genre count: 2
#
# - The Avengers (2012)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Real Steel (2011)
#   New genres: Action|Drama|Sci-Fi
#   New genre count: 3
#
# - Puss in Boots (2011)
#   New genres: Adventure|Animation|Comedy|Fantasy
#   New genre count: 4
#
# - The Adventures of Tintin (2011)
#   New genres: Action|Animation|Mystery
#   New genre count: 3
#
# - The Dark Knight Rises (2012)
#   New genres: Action|Adventure|Crime
#   New genre count: 3
#
# - The Bourne Legacy (2012)
#   New genres: Action|Adventure|Drama|Thriller
#   New genre count: 4
#
# - Mission: Impossible - Ghost Protocol (2011)
#   New genres: Action|Adventure|Thriller
#   New genre count: 3
#
# - Underworld: Awakening (2012)
#   New genres: Action|Fantasy|Horror
#   New genre count: 3
#
# - Dr. Seuss' The Lorax (2012)
#   New genres: Animation|Fantasy|Musical
#   New genre count: 3
#
# - John Carter (2012)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Dark Shadows (2012)
#   New genres: Comedy|Horror
#   New genre count: 2
#
# - Men in Black III (M.III.B.) (M.I.B.³) (2012)
#   New genres: Action|Comedy|Sci-Fi
#   New genre count: 3
#
# - Prometheus (2012)
#   New genres: Action|Horror|Sci-Fi
#   New genre count: 3
#
# - Madagascar 3: Europe's Most Wanted (2012)
#   New genres: Adventure|Animation|Children|Comedy
#   New genre count: 4
#
# - The Amazing Spider-Man (2012)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Skyfall (2012)
#   New genres: Action|Adventure|Thriller
#   New genre count: 3
#
# - Cloud Atlas (2012)
#   New genres: Drama|Sci-Fi
#   New genre count: 2
#
# - Life of Pi (2012)
#   New genres: Adventure|Drama
#   New genre count: 2
#
# - Rise of the Guardians (2012)
#   New genres: Adventure|Animation|Children|Fantasy
#   New genre count: 4
#
# - The Hobbit: An Unexpected Journey (2012)
#   New genres: Adventure|Fantasy
#   New genre count: 2
#
# - Misérables, Les (2012)
#   New genres: Drama|Musical|Romance
#   New genre count: 3
#
# - Hansel & Gretel: Witch Hunters (2013)
#   New genres: Action|Fantasy|Horror
#   New genre count: 3
#
# - A Good Day to Die Hard (2013)
#   New genres: Action|Crime|Thriller
#   New genre count: 3
#
# - Jack the Giant Slayer (2013)
#   New genres: Adventure|Fantasy
#   New genre count: 2
#
# - Oz the Great and Powerful (2013)
#   New genres: Action|Adventure|Fantasy
#   New genre count: 3
#
# - Oblivion (2013)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Iron Man 3 (2013)
#   New genres: Action|Sci-Fi|Thriller
#   New genre count: 3
#
# - Star Trek Into Darkness (2013)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Fast & Furious 6 (Fast and the Furious 6, The) (2013)
#   New genres: Action|Crime|Thriller
#   New genre count: 3
#
# - Man of Steel (2013)
#   New genres: Action|Adventure|Fantasy|Sci-Fi
#   New genre count: 4
#
# - Pacific Rim (2013)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - World War Z (2013)
#   New genres: Action|Drama|Horror
#   New genre count: 3
#
# - Elysium (2013)
#   New genres: Action|Drama|Sci-Fi
#   New genre count: 3
#
# - Despicable Me 2 (2013)
#   New genres: Animation|Children|Comedy
#   New genre count: 3
#
# - White House Down (2013)
#   New genres: Action|Drama|Thriller
#   New genre count: 3
#
# - The Lone Ranger (2013)
#   New genres: Action|Adventure|Western
#   New genre count: 3
#
# - Riddick (2013)
#   New genres: Action|Sci-Fi|Thriller
#   New genre count: 3
#
# - Gravity (2013)
#   New genres: Action|Sci-Fi
#   New genre count: 2
#
# - Captain Phillips (2013)
#   New genres: Adventure|Drama|Thriller
#   New genre count: 3
#
# - Ender's Game (2013)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Thor: The Dark World (2013)
#   New genres: Action|Adventure|Fantasy
#   New genre count: 3
#
# - The Hunger Games: Catching Fire (2013)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - The Hobbit: The Desolation of Smaug (2013)
#   New genres: Adventure|Fantasy
#   New genre count: 2
#
# - Divergent (2014)
#   New genres: Adventure|Romance|Sci-Fi
#   New genre count: 3
#
# - RoboCop (2014)
#   New genres: Action|Crime|Sci-Fi
#   New genre count: 3
#
# - Interstellar (2014)
#   New genres: Sci-Fi
#   New genre count: 1
#
# - Captain America: The Winter Soldier (2014)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Noah (2014)
#   New genres: Adventure|Drama
#   New genre count: 2
#
# - The Amazing Spider-Man 2 (2014)
#   New genres: Action|Sci-Fi
#   New genre count: 2
#
# - Transcendence (2014)
#   New genres: Drama|Sci-Fi
#   New genre count: 2
#
# - Godzilla (2014)
#   New genres: Action|Adventure|Sci-Fi
#   New genre count: 3
#
# - Maleficent (2014)
#   New genres: Action|Adventure|Children
#   New genre count: 3
#
# - Edge of Tomorrow (2014)
#   New genres: Action|Sci-Fi
#   New genre count: 2
#
# - Star Wars: Episode VII - The Force Awakens (2015)
#   New genres: Action|Adventure|Fantasy|Sci-Fi
#   New genre count: 4
#
#
# Updated dataset saved to '../backend/data/processed/filtered_movies.csv'
